# %%
# %load_ext autoreload
# %autoreload 2

# %%
import bootstrap
# Out:
# REPO_ROOT /home/daniel/Projects/meta-lifelong-learning/deep-neuroevolution/multiplai/notebooks/../..

# %%
import json
import sys
import os
from multiplai import base

# %%
TRAIN_DATA_PATH= 'multiplai/evals/nlu/nlu-benchmark/2017-06-custom-intent-engines/GetWeather/train_GetWeather_full.json'

# %%
with open(os.path.join(base.repo_root(), TRAIN_DATA_PATH),'r') as f:
    train_data = json.load(f)

# %%
train_data
# Out:
# {'GetWeather': [{'data': [{'text': 'What will the weather be '},
#     {'text': 'this year', 'entity': 'timeRange'},
#     {'text': ' in '},
#     {'text': 'Horseshoe Lake State Fish and Wildlife Area',
#      'entity': 'geographic_poi'},
#     {'text': '?'}]},
#   {'data': [{'text': 'Will it be '},
#     {'text': 'sunny', 'entity': 'condition_description'},
#     {'text': ' '},
#     {'text': 'one hundred thirty five days from now', 'entity': 'timeRange'},
#     {'text': ' in '},
#     {'text': 'Monterey Bay National Marine Sanctuary',
#      'entity': 'geographic_poi'}]},
#   {'data': [{'text': 'Is it supposed to '},
#     {'text': 'rain', 'entity': 'condition_description'},
#     {'text': ' '},
#     {'text': 'nearby', 'entity': 'spatial_relation'},
#     {'text': ' my '},
#     {'text': 'current location', 'entity': 'current_location'},
#     {'text': ' at '},
#     {'text': "0 o'clock", 'entity': 'timeRange'},
#     {'text': '?'}]},
# ...

# %%
# construct examples

# %%
from dataclasses import dataclass

# %%
@dataclass
class Example():
    a: int

# %%
# next step: 
#   figure out best way to train a classifier on this
#   bi-lstm? seq2seq? run it through twice and look at labels on the second pass?
#  might look up basic examples for NLU intent classification
